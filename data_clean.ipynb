# %%
import pandas as pd

# %%
df=pd.read_csv('customer_sales.csv')

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum()

# %%
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')
df=df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})

# %%
df.columns

# %%
# crete a column age_group 
labels=['Young Adult','Adult','Middle_Age','Senior']
df['age_group'] = pd.qcut(df['age'],q=4,labels=labels)

# %%
df[['age','age_group']].head()
# Out:
#    age    age_group
# 0   55   Middle_Age
# 1   19  Young Adult
# 2   50   Middle_Age
# 3   21  Young Adult
# 4   45   Middle_Age

# %%
df['discount_applied']==df['promo_code_used'].all()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3895    False
# 3896    False
# 3897    False
# 3898    False
# 3899    False
# Name: discount_applied, Length: 3900, dtype: bool

# %%
df=df.drop('promo_code_used', axis = 1 )

# %%
df['Review Rating']=df.groupby("Category")['Review Rating'].transform(lambda x: x.fillna(x.median()))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df['Review Rating']=df.groupby("Category")['Review Rating'].transform(lambda x: x.fillna(x.median()))
#
# File c:\Users\ry571\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# ...

# %%
pip install mysql-connector-python

# %%
pip install pymysql

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

password = quote_plus("Rakesh@2004")

engine = create_engine(
    f"mysql+mysqlconnector://root:{password}@localhost:3306/da_project_db"
)

with engine.connect() as conn:
    print("Connected successfully!")

df.to_sql('customer_sales', engine, if_exists='replace', index=False)
# Out:
# Connected successfully!
# 3900

# %%
pip install sqlalchemy

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Rakesh@2004",
    database="da_project_db"
)

query = "SELECT * FROM customer_sales"
df = pd.read_sql(query, conn)
# Out:
# C:\Users\ry571\AppData\Local\Temp\ipykernel_11728\4286541693.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
